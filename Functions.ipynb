# %% [raw]
# Function parameters

# %% [raw]
# What if you wanted to square any other number besides 4, though? To add that functionality, you add a parameter to the function definition in between the parentheses. Here you see that we've added a parameter value and in the new function body, the variable new_value takes the square of value, which is then printed out. We can now square any number that we pass to the function square as an argument. A quick word on parameters and arguments: when you define a function, you write parameters in the function header. When you call a function, you pass arguments into the function.

# %% [markdown]
# ![image.png](attachment:fc366a68-b4bd-4bc0-a7c6-b9b541ab0f27.png)

# %%
def square(value):
    new_value  = value ** 2
    return new_value

square(5)
# Out:
# [25]

# %% [markdown]
# ![image.png](attachment:5767eb6e-b903-4674-b31d-5b4503eb1d2d.png)

# %%
def square( value):
    """Raise the parameter to the power of two"""
    new_value = value **2
    return new_value
num = square(4)
print(num)
# Out:
# 16

# %%
def square( value):
    """Raise the parameter to the power of two"""
    new_value = value **2
    num = square(4)
print(num)
# Out:
# 16

# %% [markdown]
# Write a simple Function

# %%
# Define the function shout
def shout():
    """Print a string with three exclamation marks"""
    # Concatenate the strings: shout_word
    shout_word = "congratulations" + "!!!"

    # Print shout_word
    print(shout_word)

# Call shout
shout()
# Out:
# congratulations!!!

# %% [markdown]
# Single-parameter functions

# %%
# Define shout with the parameter, word
def shout(word):
    """Print a string with three exclamation marks"""
    # Concatenate the strings: shout_word
    shout_word = word + '!!!'
    # Print shout_word
    print(shout_word)
# Call shout with the string 'congratulations'
shout('Congratulations')
# Out:
# Congratulations!!!

# %% [markdown]
# Functions that return single values

# %%
# Define shout with the parameter, word
def shout(word):
    """Return a string with three exclamation marks"""
    # Concatenate the strings: shout_word
    shout_word = word + '!!!'

    # Replace print with return
    return shout_word

# Pass 'congratulations' to shout: yell
yell = shout('congratulations')

# Print yell
print(yell)
# Out:
# congratulations!!!

# %% [markdown]
# Multiple parameters and return values

# %% [markdown]
# ![image.png](attachment:9c2c89ab-20c5-49b1-80c6-3d6ac7352b2a.png)

# %% [markdown]
# ![image.png](attachment:59f3750e-2fe8-4960-8ab1-e011732633da.png)

# %%
# Define shout with parameters word1 and word2
def shout(word1, word2):
    """Concatenate strings with three exclamation marks"""
    # Concatenate word1 with '!!!': shout1
    shout1 = word1 + " to "
    
    # Concatenate word2 with '!!!': shout2
    shout2 = word2 + "!!!"
    
    # Concatenate shout1 with shout2: new_shout
    new_shout = shout1 + shout2

    # Return new_shout
    return new_shout

# Pass 'congratulations' and 'you' to shout(): yell
yell = shout('congratulations', 'you')

# Print yell
print(yell)
# Out:
# congratulations to you!!!

# %% [markdown]
# ![image.png](attachment:f47b6e16-3684-4b85-951e-b3961baa52f7.png)

# %%
# Define shout_all with parameters word1 and word2
def shout_all(word1, word2):
    """Return a tuple of strings"""
    # Concatenate word1 with '!!!': shout1
    shout1 = word1 + '!!!'
    
    # Concatenate word2 with '!!!': shout2
    shout2 = word2 + '!!!'
    
    # Construct a tuple with shout1 and shout2: shout_words
    shout_words = (shout1, shout2)

    # Return shout_words
    return shout_words

# Pass 'congratulations' and 'you' to shout_all(): yell1, yell2
yell1, yell2 = shout_all('congratulations', 'you')

# Print yell1 and yell2
print(yell1)
print(yell2)
# Out:
# congratulations!!!
# you!!!

# %%
import numpy as np
import pandas as pd
np.random.seed(123)
outcomes=[]

for i in range(10):
    coin = np.random.randint(0,2)
    if coin ==0:
        outcomes.append("heads")
    else:
        outcomes.append("tails")
print(outcomes)
# Out:
# ['heads', 'tails', 'heads', 'heads', 'heads', 'heads', 'heads', 'tails', 'tails', 'heads']

# %%
Outcomes = pd.DataFrame(outcomes)
Outcomes.value_counts()
# Out:
# heads    7
# tails    3
# dtype: int64

# %%
np.random.seed(123)
tails=[0]
for i in range (10):
    coin = np.random.randint(0,2)
    tails.append(tails[i] + coin)
print(tails)
# Out:
# [0, 0, 1, 1, 1, 1, 1, 1, 2, 3, 3]
